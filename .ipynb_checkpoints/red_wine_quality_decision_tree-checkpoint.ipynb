# %%
#https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009
import pandas as pd

# %%
wine_data = pd.read_csv('winequality-red.csv')

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
y = wine_data.quality

# %%
wine_features = ['volatile acidity', 'residual sugar', 'chlorides', 'density','total sulfur dioxide','pH']
X = wine_data[wine_features]

# %%
X.head(10)
# Out:
#    volatile acidity  residual sugar  chlorides  density  total sulfur dioxide  \
# 0              0.70             1.9      0.076   0.9978                  34.0
# 1              0.88             2.6      0.098   0.9968                  67.0
# 2              0.76             2.3      0.092   0.9970                  54.0
# 3              0.28             1.9      0.075   0.9980                  60.0
# 4              0.70             1.9      0.076   0.9978                  34.0
# 5              0.66             1.8      0.075   0.9978                  40.0
# 6              0.60             1.6      0.069   0.9964                  59.0
# 7              0.65             1.2      0.065   0.9946                  21.0
# 8              0.58             2.0      0.073   0.9968                  18.0
# 9              0.50             6.1      0.071   0.9978                 102.0
#
#      pH
# 0  3.51
# 1  3.20
# 2  3.26
# 3  3.16
# 4  3.51
# 5  3.51
# 6  3.30
# 7  3.39
# 8  3.36
# 9  3.35

# %%
X.describe()
# Out:
#        volatile acidity  residual sugar    chlorides      density  \
# count       1599.000000     1599.000000  1599.000000  1599.000000
# mean           0.527821        2.538806     0.087467     0.996747
# std            0.179060        1.409928     0.047065     0.001887
# min            0.120000        0.900000     0.012000     0.990070
# 25%            0.390000        1.900000     0.070000     0.995600
# 50%            0.520000        2.200000     0.079000     0.996750
# 75%            0.640000        2.600000     0.090000     0.997835
# max            1.580000       15.500000     0.611000     1.003690
#
#        total sulfur dioxide           pH
# count           1599.000000  1599.000000
# mean              46.467792     3.311113
# std               32.895324     0.154386
# min                6.000000     2.740000
# 25%               22.000000     3.210000
# 50%               38.000000     3.310000
# 75%               62.000000     3.400000
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
red_wine_model = DecisionTreeRegressor(random_state=1)
red_wine_model.fit(X, y) # czy jest sensu tu to robic? jesli tak, to po co
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    wine_model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=0)
    wine_model.fit(train_X, train_y)
    predictions_val = wine_model.predict(val_X) 
    mae = mean_absolute_error(val_y, predictions_val)
    return mae

# %%
for max_leaf_nodes in [5, 50, 100, 500, 1000]: # czemu wszytko ponad 500 ma taki sam błąd???
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print(f'max leaf nodes: {max_leaf_nodes} \t\t MAE: {my_mae}')
    #best one is max_leaf_nodes = 500
# Out:
# max leaf nodes: 5 		 MAE: 0.6029580753460178
# max leaf nodes: 50 		 MAE: 0.5685461631736978
# max leaf nodes: 100 		 MAE: 0.6016176887133463
# max leaf nodes: 500 		 MAE: 0.5275
# max leaf nodes: 1000 		 MAE: 0.5275

# %%
best_tree_size = 500
final_wine_model = DecisionTreeRegressor(max_leaf_nodes=best_tree_size, random_state=0)

# %%
final_wine_model.fit(X,y)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=500, random_state=0)

# %%
#co dalej?
